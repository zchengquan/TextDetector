# %%
import os

# %%
dirname = '../data/icdar2013word/'
dirlist = os.listdir(dirname)

# %%
for filename in dirlist:
    print filename
    if filename.startswidth('L'):
        f = filename.split('.')
        f = filename[0]
# Out:
# ['L_125_img_24.jpg.npy',
#  'P_128_img_58.jpg.npy',
#  'L_36_img_204.jpg.npy',
#  'P_191_img_61.jpg.npy',
#  'L_134_img_211.jpg.npy',
#  'L_225_img_140.jpg.npy',
#  'P_211_img_69.jpg.npy',
#  'P_213_img_192.jpg.npy',
#  'L_95_img_70.jpg.npy',
#  'P_111_img_78.jpg.npy',
#  'L_4_img_118.jpg.npy',
#  'P_160_img_227.jpg.npy',
#  'L_138_img_123.jpg.npy',
#  'P_30_img_178.jpg.npy',
#  'L_39_img_230.jpg.npy',
#  'P_16_img_105.jpg.npy',
#  'P_161_img_185.jpg.npy',
#  'L_5_img_73.jpg.npy',
#  'P_102_img_60.jpg.npy',
#  'P_174_img_137.jpg.npy',
#  'P_166_img_189.jpg.npy',
#  'P_104_img_187.jpg.npy',
#  'L_175_img_66.jpg.npy',
#  'P_192_img_143.jpg.npy',
#  'P_88_img_162.jpg.npy',
#  'P_81_img_224.jpg.npy',
#  'P_190_img_183.jpg.npy',
#  'L_40_img_117.jpg.npy',
#  'P_116_img_194.jpg.npy',
#  'L_208_img_191.jpg.npy',
#  'P_187_img_47.jpg.npy',
#  'P_43_img_179.jpg.npy',
#  'L_41_img_145.jpg.npy',
#  'L_12_img_10.jpg.npy',
#  'L_174_img_137.jpg.npy',
#  'P_195_img_7.jpg.npy',
# ...
