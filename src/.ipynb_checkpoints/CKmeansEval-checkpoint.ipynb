# %%
import numpy
import matplotlib.pyplot as plt

# %%
def bankShow(bank):
    ''' bankShow(bank)
    
    Show the feature banks learned by convolutional K-means
    bank: numpy array, m cluster by n features, features learned from ckmeans,
    Return: None '''
    N = 10
    i = 0
    while i < bank.shape[0]:
    
        fig = plt.figure(figsize = (15, 5)) # new figure 
        k = 1
        while k <= N:
            img = bank[i, ...]
            img = numpy.reshape(img, (8, 8))
            ax = fig.add_subplot(1, N, k)
            axis('off')
            plt.imshow(img, interpolation = 'nearest')
            k += 1
            i += 1
        plt.show()
        raw_input()
    return

# %%
# show the feature banks learned by Convolutional K-means
bankname = '../python/codeBook.npy'
data = numpy.load(bankname)
bankShow(data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9f1c248342f3> in <module>()
#       2 bankname = '../python/codeBook.npy'
#       3 data = numpy.load(bankname)
# ----> 4 bankShow(data)
#
# <ipython-input-2-c49c9e87e6cb> in bankShow(bank)
#      20             i += 1
#      21         plt.show()
# ---> 22         raw_input()
#      23     return
#
# /home/sxz8564/virtualenvs/myenv/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in <lambda>(prompt)
#     361         # raw_input in the user namespace.
#     362         if content.get('allow_stdin', False):
# --> 363             raw_input = lambda prompt='': self._raw_input(prompt, ident, parent)
#     364             input = lambda prompt='': eval(raw_input(prompt))
#     365         else:
#
# /home/sxz8564/virtualenvs/myenv/lib/python2.7/site-packages/IPython/kernel/zmq/ipkernel.pyc in _raw_input(self, prompt, ident, parent)
#     763             except KeyboardInterrupt:
#     764                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 765                 raise KeyboardInterrupt
#     766             else:
#     767                 break
#
# KeyboardInterrupt:

# %%
# show the center movement with K-means learning iterations (learning curve)
errorname = '../python/codeBookErr.npy'
err =  numpy.load(errorname) 
fig = plt.figure(figsize = (5, 5))
plt.plot(err)
plt.grid(True)
plt.xlabel('iterations')
plt.ylabel('Sum of Center Movement')
plt.title('Convolutional K-means')

# %%
# show the histogram of No. of samples contained by each cluster
idxname = '../python/codeBookIdx.npy'
idx =  numpy.load(idxname) 
fig = plt.figure(figsize = (5, 5))
n, bins, patches = plt.hist(idx, data.shape[0])
plt.grid(True)
plt.xlabel('cluster')
plt.ylabel('No. of members')
plt.title('Convolutional K-means')

# %%
sortIdx = numpy.argsort(n)[::1]
fig = plt.figure(figsize = (5, 5))
plt.plot(n[sortIdx])
plt.grid(True)
plt.xlabel('cluster (sorted)')
plt.ylabel('No. of members')
plt.title('Convolutional K-means')
bankShow(data[sortIdx, ...])

# %%
data0 = data[sortIdx, ...]
